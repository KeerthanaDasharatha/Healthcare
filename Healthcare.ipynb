# %%
# import libraries
import pandas as pd
from sqlalchemy import create_engine

import warnings
warnings.filterwarnings("ignore")

# %%
# load dataset
df=pd.read_csv(r"C:\Users\HP\Downloads\healthcare.csv")

# %%
#dimensions
df.shape
# Out:
# (55500, 15)

# %%
#first 5 dataset
df.head()
# Out:
#             Name  Age  Gender Blood_Type Medical_Condition  Date_of_Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer              45322
# 1   LesLie TErRy   62    Male         A+           Obesity              43697
# 2    DaNnY sMitH   76  Female         A-           Obesity              44826
# 3   andrEw waTtS   28  Female         O+          Diabetes              44153
# 4  adrIENNE bEll   43  Female        AB+            Cancer              44823
#
#              Doctor                    Hospital Insurance_Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing_Amount  Room_Number Admission_Type  Discharge_Date   Medication  \
# ...

# %%
#last 5 dataset
df.tail()
# Out:
#                     Name  Age  Gender Blood_Type Medical_Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#        Date_of_Admission           Doctor                      Hospital  \
# 55495              44059    Joshua Jarvis                Jones-Thompson
# 55496              43853  Taylor Sullivan                  Tucker-Moyer
# 55497              44025   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498              43610   Kimberly Curry      Jackson Todd and Castro,
# 55499              45384    Dennis Warren                Henry Sons and
#
#       Insurance_Provider  Billing_Amount  Room_Number Admission_Type  \
# ...

# %%
# informatiom of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood_Type          55500 non-null  object
#  4   Medical_Condition   55500 non-null  object
#  5   Date_of_Admission   55500 non-null  int64
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance_Provider  55500 non-null  object
#  9   Billing_Amount      55500 non-null  float64
#  10  Room_Number         55500 non-null  int64
#  11  Admission_Type      55500 non-null  object
#  12  Discharge_Date      55500 non-null  int64
#  13  Medication          55500 non-null  object
#  14  Test_Results        55500 non-null  object
# ...

# %%
# coverting object to date format
df["Date_of_Admission"]=pd.to_datetime(df["Date_of_Admission"])
df["Discharge_Date"] = pd.to_datetime(df["Discharge_Date"])

# %%
df['Num_of_Days_at_hospital'] = (df['Discharge_Date'] - df['Date_of_Admission']).dt.days
df.drop(['Name', 'Date_of_Admission', 'Discharge_Date'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Age                          int64
# Gender                      object
# Blood_Type                  object
# Medical_Condition           object
# Doctor                      object
# Hospital                    object
# Insurance_Provider          object
# Billing_Amount             float64
# Room_Number                  int64
# Admission_Type              object
# Medication                  object
# Test_Results                object
# Num_of_Days_at_hospital      int64
# dtype: object

# %%
# finding null values
df.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Blood_Type                 0
# Medical_Condition          0
# Doctor                     0
# Hospital                   0
# Insurance_Provider         0
# Billing_Amount             0
# Room_Number                0
# Admission_Type             0
# Medication                 0
# Test_Results               0
# Num_of_Days_at_hospital    0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Billing_Amount   Room_Number  Num_of_Days_at_hospital
# count  55500.000000    55500.000000  55500.000000                  55500.0
# mean      51.539459    25539.316097    301.134829                      0.0
# std       19.602454    14211.454431    115.243069                      0.0
# min       13.000000    -2008.492140    101.000000                      0.0
# 25%       35.000000    13241.224655    202.000000                      0.0
# 50%       52.000000    25538.069380    302.000000                      0.0
# 75%       68.000000    37820.508432    401.000000                      0.0
# max       89.000000    52764.276740    500.000000                      0.0

# %%
username = 'root'
password = 'keert1701'
port = 127
host = 3306
database = 'health'

engine = create_engine("mysql+pymysql://root:keert1701@localhost:3306/health")

# %%
df.to_sql("healthcare",con=engine,if_exists='replace',index='False')
# Out:
# 55500
